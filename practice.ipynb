# %%
from langchain_aws import ChatBedrockConverse

llm = ChatBedrockConverse(
    model_id="qwen.qwen3-next-80b-a3b",
    region_name= "us-east-1"

)

# %%
llm.invoke("Hi")
# Out:
# AIMessage(content="Hello! How can I assist you today? If you have any questions or need information on a particular topic, feel free to ask. Whether it's about science, technology, history, or something else, I'm here to help.", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '3e6a38c9-4bd2-4f42-9bdc-2530c01b7343', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 12 Mar 2026 19:35:27 GMT', 'content-type': 'application/json', 'content-length': '408', 'connection': 'keep-alive', 'x-amzn-requestid': '3e6a38c9-4bd2-4f42-9bdc-2530c01b7343'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [485]}, 'model_provider': 'bedrock_converse', 'model_name': 'amazon.nova-lite-v1:0'}, id='lc_run--019ce38b-f172-7c61-81cd-a9af48cfe773-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1, 'output_tokens': 50, 'total_tokens': 51, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}})
